# %% [markdown]
# <a href="https://colab.research.google.com/github/geniuschinchillas/ChinchillasSnack/blob/master/GenerateData/make_circles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
from sklearn.datasets import samples_generator as sg

# %% [markdown]
# **make_circles**

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples = 400, factor=.3, noise=.05)

# %%
print(X.shape)
# Out:
# (400, 2)

# %%
reds = y == 0
blues = y == 1

# %%
plt.figure(figsize=(10, 10))

plt.scatter(X[reds,0], X[reds,1], c='r')
plt.scatter(X[blues,0], X[blues,1], c='b')

plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

ax.scatter(X[reds,0], X[reds,1], c='r')
ax.scatter(X[blues,0], X[blues,1], c='b')

plt.show()
